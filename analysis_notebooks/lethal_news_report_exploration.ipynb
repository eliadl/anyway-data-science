# %%
import pandas as pd
# %matplotlib inline

# %%
csv_path = '../views_2019/markers_hebrew.csv'
df = pd.read_csv(csv_path)
# Out:
# /Users/eliadlevy/src/anyway-data-science/.venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (23,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#            id  provider_and_id  provider_code  \
# 0  2009000007      12009000007              1
# 1  2017006880      32017006880              3
# 2  2009054349      32009054349              3
# 3  2012000013      12012000013              1
# 4  2019019112      12019019112              1
#
#                    provider_code_hebrew  file_type_police  accident_type  \
# 0  הלשכה המרכזית לסטטיסטיקה - סוג תיק 1               NaN              1
# 1  הלשכה המרכזית לסטטיסטיקה - סוג תיק 3               NaN              3
# 2  הלשכה המרכזית לסטטיסטיקה - סוג תיק 3               NaN             10
# 3  הלשכה המרכזית לסטטיסטיקה - סוג תיק 1               NaN              1
# 4  הלשכה המרכזית לסטטיסטיקה - סוג תיק 1               1.0              5
#
#   accident_type_hebrew  accident_severity accident_severity_hebrew  \
# 0      פגיעה בהולך רגל                  3                      קלה
# 1   התנגשות חזית באחור                  3                      קלה
# ...

# %%
query = df[
    (df.yishuv_name == 'רמת גן') &
    (df.street1_hebrew == 'אלוף דוד')
]

query.head()
# Out:
#                id  provider_and_id  provider_code  \
# 5450   2019022473      12019022473              1
# 13937  2008011656      12008011656              1
# 14064  2008013304      12008013304              1
# 14827  2008016239      12008016239              1
# 15627  2008021119      12008021119              1
#
#                        provider_code_hebrew  file_type_police  accident_type  \
# 5450   הלשכה המרכזית לסטטיסטיקה - סוג תיק 1               1.0              2
# 13937  הלשכה המרכזית לסטטיסטיקה - סוג תיק 1               NaN              2
# 14064  הלשכה המרכזית לסטטיסטיקה - סוג תיק 1               NaN              2
# 14827  הלשכה המרכזית לסטטיסטיקה - סוג תיק 1               NaN              2
# 15627  הלשכה המרכזית לסטטיסטיקה - סוג תיק 1               NaN              1
#
#       accident_type_hebrew  accident_severity accident_severity_hebrew  \
# 5450      התנגשות חזית בצד                  3                      קלה
# ...

# %%
query.groupby('accident_type_hebrew').count()['id']
# Out:
# accident_type_hebrew
# אחר                           6
# החלקה                         2
# התהפכות                       1
# התנגשות אחור אל צד            1
# התנגשות אחור בחזית            1
# התנגשות חזית אל צד           16
# התנגשות חזית באחור            9
# התנגשות חזית בחזית            2
# התנגשות חזית בצד             10
# התנגשות עם עצם דומם           1
# התנגשות עם רכב חונה           5
# התנגשות צד בצד               10
# נפילה מרכב נע                 1
# פגיעה בהולך רגל              11
# פגיעה בנוסע בתוך כלי הרכב     4
# Name: id, dtype: int64
